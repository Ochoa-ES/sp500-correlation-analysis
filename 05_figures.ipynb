# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
# %matplotlib inline
from __future__ import division
import numpy as np
from numpy import linalg as LA
from scipy import linalg
from scipy import stats
from pylab import * 
import matplotlib
#from tempfile import TemporaryFileRandom matrices: time series correlation matrices
P = open("Prices.txt","rb")
S = open("Symbols.txt","r")
D = open("Dates.txt","r")
G = open("Gics.txt","r")
matplotlib.style.use("ggplot")

# %%
year=[] 
for i in range(23): 
    anios=1992 
    anios=+(anios+i) 
    year.append(anios) 
len(year)
# Out:
# 23

# %%
s=[]
lines=S.readlines()
S.close()
for line in lines:
	values = line.split()
	s.append(values[0])
lensymbols=len(s)

d=[]
lines=D.readlines()
D.close() 
for line in lines:
	values = line.split()
	d.append(values[0])
#print type(values)	
lendates=len(d)

g=[]
lines=G.readlines()
G.close()
for line in lines:
	values = line.split()
	g.append(values[0])
    
Prices=np.loadtxt("Prices.txt")      
lenPrices=len(Prices)

# %%
#----- Rendimientos---

Returns=[]

for i in range(lensymbols):
    Returns.append([])
    for j in range(1,lendates):
        r=(Prices[i][j-1]/Prices[i][j])-1
        Returns[-1].append(r)
Returns=np.asarray(Returns)
#print len(Returns)

# %%
# %matplotlib notebook
for x in range(len(Returns)):
    plt.plot(Returns[x])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="904">

# %%
rcParams['figure.figsize'] = 16, 6
T=20

shift=1
lenret=len(Returns)
nummat=(len(Returns[0])-shift)/shift
salto=nummat/23
xx=np.arange(0,nummat,salto)

fig, ax1 = plt.subplots()

CPmean=np.load("/home/lmzg/Python_Notebooks/Data_Management/power_mapping/Cmean/Cm%d.npy"%T)
negativo=np.load("Negative%d.npy"%T)
color = 'tab:red'
#ax1.set_xlabel('time (s)')
ax1.set_ylabel(r"$ \langle C_{ij}\rangle$", color=color)
ax1.plot(CPmean[::], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticklabels(year,rotation=90)
ax1.set_xticks(xx)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('no. negative values', color=color)  # we already handled the x-label with ax1
ax2.plot(negativo[::], color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title("T=%d"%T, fontsize=18)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-20df7bd33167> in <module>()
# ----> 1 fig
#
# NameError: name 'fig' is not defined

# %%
rcParams['figure.figsize'] = 16, 6
T=21

shift=1
lenret=len(Returns)
nummat=(len(Returns[0])-shift)/shift
salto=nummat/23
xx=np.arange(0,nummat,salto)

fig, ax1 = plt.subplots()

CPmean=np.load("/home/lmzg/Python_Notebooks/Data_Management/power_mapping/Cmean/Cm%d.npy"%T)
negativo=np.load("Negative%d.npy"%T)
color = 'tab:red'
#ax1.set_xlabel('time (s)')
ax1.set_ylabel(r"$ \langle C_{ij}\rangle$", color=color)
ax1.plot(CPmean[::], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticklabels(year,rotation=90)
ax1.set_xticks(xx)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('no. negative values', color=color)  # we already handled the x-label with ax1
ax2.plot(negativo[::], color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title("T=%d"%T, fontsize=18)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
rcParams['figure.figsize'] = 16, 6
T=22

shift=1
lenret=len(Returns)
nummat=(len(Returns[0])-shift)/shift
salto=nummat/23
xx=np.arange(0,nummat,salto)

fig, ax1 = plt.subplots()

CPmean=np.load("/home/lmzg/Python_Notebooks/Data_Management/power_mapping/Cmean/Cm%d.npy"%T)
negativo=np.load("Negative%d.npy"%T)
color = 'tab:red'
#ax1.set_xlabel('time (s)')
ax1.set_ylabel(r"$ \langle C_{ij}\rangle$", color=color)
ax1.plot(CPmean[::], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticklabels(year,rotation=90)
ax1.set_xticks(xx)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('no. negative values', color=color)  # we already handled the x-label with ax1
ax2.plot(negativo[::], color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title("T=%d"%T, fontsize=18)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
rcParams['figure.figsize'] = 16, 6
T=60

shift=1
lenret=len(Returns)
nummat=(len(Returns[0])-shift)/shift
salto=nummat/23
xx=np.arange(0,nummat,salto)

fig, ax1 = plt.subplots()

CPmean=np.load("/home/lmzg/Python_Notebooks/Data_Management/power_mapping/Cmean/Cm%d.npy"%T)
negativo=np.load("Negative%d.npy"%T)
color = 'tab:red'
#ax1.set_xlabel('time (s)')
ax1.set_ylabel(r"$ \langle C_{ij}\rangle$", color=color)
ax1.plot(CPmean[::], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticklabels(year,rotation=90)
ax1.set_xticks(xx)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('no. negative values', color=color)  # we already handled the x-label with ax1
ax2.plot(negativo[::], color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title("T=%d"%T, fontsize=18)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
rcParams['figure.figsize'] = 16, 6
T=30

shift=1
lenret=len(Returns)
nummat=(len(Returns[0])-shift)/shift
salto=nummat/23
xx=np.arange(0,nummat,salto)

fig, ax1 = plt.subplots()

CPmean=np.load("/home/lmzg/Python_Notebooks/Data_Management/power_mapping/Cmean/Cm%d.npy"%T)
negativo=np.load("Negative%d.npy"%T)
color = 'tab:red'
#ax1.set_xlabel('time (s)')
ax1.set_ylabel(r"$ \langle C_{ij}\rangle$", color=color)
ax1.plot(CPmean[::], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticklabels(year,rotation=90)
ax1.set_xticks(xx)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('no. negative values', color=color)  # we already handled the x-label with ax1
ax2.plot(negativo[::], color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title("T=%d"%T, fontsize=18)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
rcParams['figure.figsize'] = 16, 6
T=15

shift=1
lenret=len(Returns)
nummat=(len(Returns[0])-shift)/shift
salto=nummat/23
xx=np.arange(0,nummat,salto)

fig, ax1 = plt.subplots()

CPmean=np.load("/home/lmzg/Python_Notebooks/Data_Management/power_mapping/Cmean/Cm%d.npy"%T)
negativo=np.load("Negative%d.npy"%T)
color = 'tab:red'
#ax1.set_xlabel('time (s)')
ax1.set_ylabel(r"$ \langle C_{ij}\rangle$", color=color)
ax1.plot(CPmean[::], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticklabels(year,rotation=90)
ax1.set_xticks(xx)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('no. negative values', color=color)  # we already handled the x-label with ax1
ax2.plot(negativo[::], color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.title("T=%d"%T, fontsize=18)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
#correlacion entre valores negativos y corr prom
t=22
rcParams['figure.figsize'] = 16, 6
plt.figure(1)

plt.subplot(111)
T=15
corlist=np.load("Corlist%d.npy"%T)
plt.plot(corlist,label="T=%d"%T)
plt.legend()

plt.subplot(111)
T=30
corlist=np.load("Corlist%d.npy"%T)
plt.plot(corlist,label="T=%d"%T)
plt.legend()

plt.subplot(111)
T=18
corlist=np.load("Corlist%d.npy"%T)
plt.plot(corlist,label="T=%d"%T, color="green")
plt.legend()
salto=(nummat/t)/23
xx=np.arange(0,nummat/t,salto)
plt.xticks(xx,year,rotation=90);
# Out:
# /home/lmzg/miniconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
#t=22          #tamaño de ventana para la correlacion entre valores negativos y mean corr

T=60
N=293
q=1.0010
shift=1
lenret=len(Returns)
nummat=(len(Returns[0])-shift)/shift

CPmean=np.load("/home/lmzg/Python_Notebooks/Data_Management/power_mapping/Cmean/Cm%d.npy"%T)
#CPstd=np.load("/home/lmzg/Python_Notebooks/Data_Management/power_mapping/Cmean/Cstd%d.npy"%T)
neganum1=np.load("Negative%d.npy"%T)


k=0
mat=np.zeros((2,t))
corlist=[]
corr=np.zeros((2,2))
numventanas=int((len(neganum1))/t)
                    
for j in range(numventanas):
    
    for z in range(t):
        mat[0][z]=CPmean[z+k]
        mat[1][z]=neganum1[z+k]

    k+=t
    for i in range(2):
        mean=np.mean(mat[i])
        
        var=np.std(mat[i])
        #print mean, var
        #mat[i]=(mat[i]-mean)/var
    #mat=np.array(mat)
    corr=np.corrcoef(mat)
    corlist.append(corr[0][1])
    mat=np.zeros((2,t))
    corr=np.zeros((2,2))
title="Corlist%d"%T
np.save(title,corlist)
